# %%
import pandas as pd

# %%
question_csv = '../csv/question_talk_data.csv' #  質問チャンネルのcsvファイルの名前

# %%
df_question = pd.read_csv(question_csv) #  質問チャンネルのcsvファイルをDataFrameに変換する

# %%
df_question
# Out:
#        channel_id  channel_name  reply_num      user_id  \
# 0       CJCNV9LG2   03-01-質問-実務          0    URDDX224S
# 1     C014QPLTKKN   03-02-質問-学習          0    URDDX224S
# 2     C014BS723RC  03-03-質問-その他          0    URDDX224S
# 3     C014BS723RC  03-03-質問-その他          1    UT5FYCM6D
# 4     C014BS723RC  03-03-質問-その他          2    URDDX224S
# 5     C014BS723RC  03-03-質問-その他          0    URDDX224S
# 6       CJCNV9LG2       03-1-質問          0    UKU6PP3J5
# 7       CJCNV9LG2       03-1-質問          1    UJRAL005U
# 8       CJCNV9LG2       03-1-質問          2    UJRAL005U
# 9       CJCNV9LG2       03-1-質問          3    UJRAL005U
# 10      CJCNV9LG2       03-1-質問          4    UKU6PP3J5
# 11      CJCNV9LG2       03-1-質問          5    UKU6PP3J5
# 12      CJCNV9LG2       03-1-質問          6    UJRAL005U
# 13      CJCNV9LG2       03-1-質問          7    UKU6PP3J5
# 14      CJCNV9LG2       03-1-質問          8    UJRAL005U
# 15      CJCNV9LG2       03-1-質問          9    UJRAL005U
# ...

# %%
class setup:
    @classmethod
    def

# %%
setup()
  user_master = create_user_master(pd.read_csv)
